# %%
import pandas as pd
import numpy as np
import re

df = pd.read_csv(r"C:\Users\User\Desktop\Launch Code\Final project\Online Job Posting Dataset.csv")

# %%
df.head()
# Out:
#                                              jobpost       date  \
# 0  AMERIA Investment Consulting Company\r\nJOB TI...   5-Jan-04
# 1  International Research & Exchanges Board (IREX...   7-Jan-04
# 2  Caucasus Environmental NGO Network (CENN)\r\nJ...   7-Jan-04
# 3  Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n...   7-Jan-04
# 4  Yerevan Brandy Company\r\nJOB TITLE:  Software...  10-Jan-04
#
#                                                Title  \
# 0                            Chief Financial Officer
# 1  Full-time Community Connections Intern (paid i...
# 2                                Country Coordinator
# 3                                     BCC Specialist
# 4                                 Software Developer
#
#                                            Company AnnouncementCode Term  \
# 0             AMERIA Investment Consulting Company              NaN  NaN
# 1  International Research & Exchanges Board (IREX)              NaN  NaN
# ...

# %%
df.drop(columns=["AnnouncementCode", "Eligibility", "Audience", "Notes", "Attach"], inplace= True )

# %%
df.head()
# Out:
#                                              jobpost       date  \
# 0  AMERIA Investment Consulting Company\r\nJOB TI...   5-Jan-04
# 1  International Research & Exchanges Board (IREX...   7-Jan-04
# 2  Caucasus Environmental NGO Network (CENN)\r\nJ...   7-Jan-04
# 3  Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n...   7-Jan-04
# 4  Yerevan Brandy Company\r\nJOB TITLE:  Software...  10-Jan-04
#
#                                                Title  \
# 0                            Chief Financial Officer
# 1  Full-time Community Connections Intern (paid i...
# 2                                Country Coordinator
# 3                                     BCC Specialist
# 4                                 Software Developer
#
#                                            Company Term StartDate  \
# 0             AMERIA Investment Consulting Company  NaN       NaN
# 1  International Research & Exchanges Board (IREX)  NaN       NaN
# ...

# %%
df.drop(columns = ["jobpost", "date", "Salary", "ApplicationP", "OpeningDate", "Deadline"], inplace = True)

# %%
df.shape
# Out:
# (19001, 13)

# %%
nan_counts = df.isna().sum()

# %%
print(nan_counts)
# Out:
# Title                28
# Company               7
# Term              11325
# StartDate          9326
# Duration           8203
# Location             32
# JobDescription     3892
# JobRequirment      2522
# RequiredQual        484
# AboutC             6531
# Year                  0
# Month                 0
# IT                    0
# dtype: int64

# %%
df = df.drop(df[df["JobDescription"].str.lower() == "nan"].index)

# %%
df.drop(columns = ["StartDate", "Duration","Location"], inplace = True)

# %%
df.insert(0, "PostNumber", range(1, len(df) + 1))
